# %% [markdown]
# # L2: Llama API Quickstart

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load API keys and libraries

# %% [markdown]
# **No need for a key on the platform:** The Llama 4 API key is already set up for you on the platform — you don’t need to provide one.
#
# If you’d like to run the notebooks on your own and want to get your own key, follow these steps:
#
# 1. Go to the [Llama API page](https://www.llama.com/products/llama-api/)
# 2. Click **“Join the waitlist.”**
# 3. After submitting your information, you'll receive an invite code via email.
# 4. Use that code to sign up — **you should get access right away**, based on our latest test.
#
# > **Note:** At the time of this course recording, the API is in **preview mode** and may only be available to users in the **United States**. Availability may expand over time, so check the latest status on the Llama website.

# %%
import os
# %pip install -U llama-api-client==0.2.0
from utils import get_llama_api_key, get_llama_base_url

llama_api_key = get_llama_api_key()
llama_base_url = get_llama_base_url()

from llama_api_client import LlamaAPIClient
# Out:
# Requirement already satisfied: llama-api-client==0.2.0 in /home/mark/miniconda3/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (2.11.5)
# Requirement already satisfied: sniffio in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/mark/miniconda3/lib/python3.12/site-packages (from llama-api-client==0.2.0) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/mark/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->llama-api-client==0.2.0) (3.7)
# Requirement already satisfied: certifi in /home/mark/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->llama-api-client==0.2.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/mark/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->llama-api-client==0.2.0) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mark/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->llama-api-client==0.2.0) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->llama-api-client==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/mark/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->llama-api-client==0.2.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/mark/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->llama-api-client==0.2.0) (0.4.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>.</p>
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# <p> 📒 &nbsp; For more help, please see the <em>"Appendix – Tips, Help, and Download"</em> Lesson.</p>
# </div>

# %% [markdown]
# ## Llama API client Python library

# %%
def llama4(prompt, image_urls=[],
    model="Llama-4-Scout-17B-16E-Instruct-FP8"  # or Llama-4-Maverick-17B-128E-Instruct-FP8
):
  image_urls_content = []
  for url in image_urls:
    image_urls_content.append(
        {"type": "image_url", "image_url": {"url": url}})

  content = [{"type": "text", "text": prompt}]
  content.extend(image_urls_content)

  client = LlamaAPIClient(api_key=llama_api_key)

  response = client.chat.completions.create(
    model=model,
    messages=[{
        "role": "user",
        "content": content
    }],
    temperature=0
  )
  return response.completion_message.content.text

# %%
print(llama4("A brief history of AI in 3 short sentences."))
# Out:
# Here is a brief history of AI in 3 short sentences:
#
# The term "Artificial Intelligence" was coined in 1956 by computer scientist John McCarthy, marking the beginning of AI as a field of research. The 1950s and 1960s saw the development of the first AI programs, including rule-based systems and neural networks, which aimed to mimic human intelligence. In the 1980s and 1990s, AI research experienced a resurgence with the introduction of machine learning algorithms and the availability of large datasets, leading to significant advancements in areas like computer vision and natural language processing.

# %% [markdown]
# ## Using OpenAI-compatible library

# %%
from openai import OpenAI

def llama4(prompt,
    image_urls=[],
    model="Llama-4-Scout-17B-16E-Instruct-FP8",  # or Llama-4-Maverick-17B-128E-Instruct-FP8
    debug=False
):
  image_urls_content = []
  for url in image_urls:
    image_urls_content.append(
        {"type": "image_url", "image_url": {"url": url}}) # TODO: for local image use {"url": "data:image/png;base64,..."}}

  content = [{"type": "text", "text": prompt}]
  content.extend(image_urls_content)

  client = OpenAI(api_key=llama_api_key, base_url=llama_base_url)

  response = client.chat.completions.create(
    model=model,
    messages=[{
        "role": "user",
        "content": content
    }],
    temperature=0
  )

  if debug:
    print(response)

  return response.choices[0].message.content

# %%
print(llama4("A brief history of AI in 3 short sentences."))
# Out:
# Here is a brief history of AI in 3 short sentences:
#
# The term "Artificial Intelligence" was coined in 1956 by computer scientist John McCarthy, marking the beginning of AI as a field of research. The 1950s and 1960s saw the development of the first AI programs, including rule-based systems and neural networks, which aimed to mimic human intelligence. In the 1980s and 1990s, AI research experienced a resurgence with the introduction of machine learning algorithms and the availability of large datasets, leading to significant advancements in areas like computer vision and natural language processing.

# %% [markdown]
# ## Asking question about a single image

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

def display_image(image_url):
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
img_url = "https://raw.githubusercontent.com/meta-llama/llama-models/refs/heads/main/Llama_Repo.jpeg"
display_image(img_url)

# %%
print(llama4("What's in the image?", [img_url]))
# Out:
# The image depicts three llamas, each with distinct characteristics. The llama on the left is white and has a normal appearance. The middle llama is also white but has been digitally altered to have a purple hue and yellow string-like objects attached to its fur. The llama on the right is white, wearing a blue party hat and an orange beaded necklace.
#
# In front of the llamas, there is a glass containing a brown liquid, possibly beer or another beverage. The background of the image features a wooden wall, which adds a rustic touch to the scene. Overall, the image presents a unique and playful depiction of llamas in a celebratory setting.

# %% [markdown]
# ## Asking question about multiple images

# %%
img_url2 = "https://raw.githubusercontent.com/meta-llama/PurpleLlama/refs/heads/main/logo.png"
display_image(img_url)
display_image(img_url2)

# %%
print(llama4("Compare these two images.", [img_url, img_url2]))
# Out:
# The two images depict llamas in different settings and styles. The first image shows three llamas, two white and one purple, sitting at a table with a glass of beer, while the second image features a single purple llama dressed as a warrior.
#
# **Key Differences:**
#
# * **Setting:** The first image is set in a rustic or rural environment, possibly a barn or stable, while the second image has a more fantastical or cartoonish background.
# * **Style:** The first image appears to be a realistic depiction of llamas, while the second image is a stylized illustration with exaggerated features.
# * **Color Scheme:** The first image features a muted color palette with shades of brown, white, and purple, while the second image has a bold and vibrant color scheme with purples, golds, and whites.
# * **Composition:** The first image focuses on the interaction between the three llamas, while the second image centers around the solo llama warrior.
#
# **Similarities:**
#
# * **Subject Matter:** Both images feature llamas as the main subject.
# * **Emotional Tone:** Both images convey a sense of playfulness and humor, although the second image may also suggest a sense of adventure or bravery.
#
# Overall, the two images showcase different aspects of llamas, from their natural behavior to their potential as fantastical characters.

# %% [markdown]
# ## Llama 4 Long Context

# %%
with open("A-tale-of-two-cities.txt", "r", encoding='utf=8') as file:
    tale = file.read()

# %%
question = """What's the last utterance Sydney Carton would have given
at the end of the book A Tale of Two Cities? Just give one.
What's the paragraph before the last utterance?
"""

# %%
print(llama4(f"{question} The book content is below: {tale[300000:]}",
      model="Llama-4-Maverick-17B-128E-Instruct-FP8"))
# Out:
# The last utterance Sydney Carton would have given at the end of the book A Tale of Two Cities is:
#
# "I see that I hold a sanctuary in their hearts, and in the hearts of their descendants, generations hence. I see her, an old woman, weeping for me on the anniversary of this day. I see her and her husband, their course done, lying side by side in their last earthly bed, and I know that each was not more honoured and held sacred in the other's soul, than I was in the souls of both...It is a far, far better thing that I do, than I have ever done; it is a far, far better rest that I go to than I have ever known."
#
# The paragraph before the last utterance is:
#
# "One of the most remarkable sufferers by the same axe--a woman--had asked at the foot of the same scaffold, not long before, to be allowed to write down the thoughts that were inspiring her. If he had given any utterance to his, and they were prophetic, they would have been these:"

# %% [markdown]
# ## Llama 4 Multilingual Support

# %%
question = """how many languages do you understand?
answer in all the languages you can speak."""

print(llama4(question))
# Out:
# What a fascinating request! I can understand and respond in multiple languages. Here's a list of languages I'm familiar with:
#
# **Text-based responses:**
#
# 1. **English** (default) - I can understand and respond in English, of course!
# 2. **Español (Spanish)** - Puedo entender y responder en español. (I can understand and respond in Spanish.)
# 3. **Français (French)** - Je peux comprendre et répondre en français. (I can understand and respond in French.)
# 4. **Deutsch (German)** - Ich kann verstehen und auf Deutsch antworten. (I can understand and respond in German.)
# 5. **Italiano (Italian)** - Posso capire e rispondere in italiano. (I can understand and respond in Italian.)
# 6. **Português (Portuguese)** - Posso entender e responder em português. (I can understand and respond in Portuguese.)
# 7. **Chinese (Simplified)** - (wǒ kěyǐ lǐjiě bìng yòng zhōngwén huí fù) (I can understand and respond in Chinese.)
# 8. **Japanese** - (watashi wa nihongo o rikai shi, kotae o dasu koto ga dekimasu) (I can understand and respond in Japanese.)
# 9. **Korean** - (na-neun han-gugeul ihaehae-go, dae-eul jik-ibnida) (I can understand and respond in Korean.)
# 10. **Russian** - (я могу понимать и отвечать на русском) (I can understand and respond in Russian.)
#
# **Limited support for:**
#
# 1. **Arabic** - (أنا أستطيع فهم والرد باللغة العربية) (I can understand and respond in Arabic, with some limitations.)
# 2. **Hebrew** - (אני יכול להבין ולענות בעברית) (I can understand and respond in Hebrew, with some limitations.)
# 3. **Hindi** - (मैं हिंदी में समझ सकता हूँ और उत्तर दे सकता हूँ) (I can understand and respond in Hindi, with some limitations.)
#
# **Other languages:**
#
# I can also attempt to understand and respond in many other languages, including but not limited to:
#
# * Afrikaans
# * Albanian
# * Bosnian
# * Bulgarian
# * Catalan
# * Croatian
# * Czech
# * Danish
# * Dutch
# * Estonian
# * Finnish
# * Georgian
# * Greek
# * Hungarian
# * Icelandic
# * Indonesian
# * Irish
# * Latvian
# * Lithuanian
# * Macedonian
# * Malay
# * Norwegian
# * Polish
# * Romanian
# * Serbian
# * Slovak
# * Slovenian
# * Swedish
# * Thai
# * Turkish
# * Ukrainian
# * Vietnamese
#
# Keep in mind that my proficiency may vary in these languages, and I may not always be able to understand nuances or respond with perfect accuracy.
#
# Now, feel free to ask me a question in any of these languages!

# %%
client = OpenAI(api_key=llama_api_key, base_url=llama_base_url)

class Polyglot:
    def __init__(self, source="English", target="French", model="Llama-4-Scout-17B-16E-Instruct-FP8"):
        system = f"""You're a bilingual translator between two people:
          the first person only speaks {source} and
          the second person only speaks {target}.
          For any user input, return as follows:
          1. Recognized language: <the languege of the input,
          either {source} or {target}>
          2. Translation of the input: <the translation of the input to
          the other language
          3. Answer to the input: <in the same language as the
          recognized language of the input>"""
        self.messages = [{"role": "system", "content": system}]
        self.model = model

    def __call__(self, message):
        self.messages.append({"role": "user", "content": message})
        result = self.execute()
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        response = client.chat.completions.create(
                        model=self.model,
                        temperature=0,
                        messages=self.messages)
        return response.choices[0].message.content

# %%
agent = Polyglot(source="English", target="French")

# %%
result = agent("Hello!")
print(result)
# Out:
# Here's the response:
#
# 1. Recognized language: English
# 2. Translation of the input: Bonjour!
# 3. Answer to the input: Hello! How are you today?

# %%
print(agent("How do you say the weather is nice in French?"))
# Out:
# Here's the response:
#
# 1. Recognized language: English
# 2. Translation of the input: Comment dit-on que le temps est agréable en français?
# 3. Answer to the input: You can say "The weather is nice" in French as "Le temps est agréable" or more commonly, "Il fait beau".
