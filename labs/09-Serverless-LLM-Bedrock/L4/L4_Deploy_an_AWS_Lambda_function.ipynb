# %% [markdown]
# # Lesson 4: Deploy an AWS Lambda function

# %% [markdown]
# ### Import all needed packages

# %%
import boto3, os

# %%
from helpers.Lambda_Helper import Lambda_Helper
from helpers.S3_Helper import S3_Helper
from helpers.Display_Helper import Display_Helper

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
# os.environ['LAMBDALAYERVERSIONARN'] = 'arn:aws:lambda:us-west-2:092413168457:layer:dlai-bedrock-jinja-layer:1'

# %%
lambda_helper = Lambda_Helper()
# deploy_function
# add_lambda_trigger

# %%
s3_helper = S3_Helper()
# upload_file
# download_object 
# list_objects

# %%
display_helper = Display_Helper()
# text_file
# json_file

# %%
bucket_name_text = os.getenv('BucketName')

# %%
# %%writefile prompt_template.txt
# I need to summarize a conversation. The transcript of the conversation is between the <data> XML like tags.
#
# <data>
# {{transcript}}
# </data>
#
# The summary must contain a one word sentiment analysis, and a list of issues, problems or causes of friction
# during the conversation. The output must be provided in JSON format shown in the following example.
#
# Example output:
# {
#     "version": 0.1,
#     "sentiment": <sentiment>,
#     "issues": [
#         {
#             "topic": <topic>,
#             "summary": <issue_summary>,
#         }
#     ]
# }
#
# An `issue_summary` must only be one of:
# {%- for topic in topics %}
#  - `{{topic}}`
# {% endfor %}
#
# Write the JSON output and nothing more.
#
# Here is the JSON output:
# Out:
# Overwriting prompt_template.txt

# %%
display_helper.text_file('prompt_template.txt')
# Out:
# prompt_template.txt:
# <div style='width: 600px; word-wrap: break-word;'><pre>I need to summarize a conversation. The transcript of the conversation is between the &lt;data&gt; XML like tags.<br><br>&lt;data&gt;<br>{{transcript}}<br>&lt;/data&gt;<br><br>The summary must contain a one word sentiment analysis, and a list of issues, problems or causes of friction<br>during the conversation. The output must be provided in JSON format shown in the following example. <br><br>Example output:<br>{<br>    &quot;version&quot;: 0.1,<br>    &quot;sentiment&quot;: &lt;sentiment&gt;,<br>    &quot;issues&quot;: [<br>        {<br>            &quot;topic&quot;: &lt;topic&gt;,<br>            &quot;summary&quot;: &lt;issue_summary&gt;,<br>        }<br>    ]<br>}<br><br>An `issue_summary` must only be one of:<br>{%- for topic in topics %}<br> - `{{topic}}`<br>{% endfor %}<br><br>Write the JSON output and nothing more.<br><br>Here is the JSON output:<br></pre></div>

# %% [markdown]
# ### Create the Lambda function

# %%
# %%writefile lambda_function.py


#############################################################
#
# This Lambda function is written to a file by the notebook 
# It does not run in the notebook!
#
#############################################################

import boto3
import json 
from jinja2 import Template

s3_client = boto3.client('s3')
bedrock_runtime = boto3.client('bedrock-runtime', 'us-west-2')

def lambda_handler(event, context):
    
    bucket = event['Records'][0]['s3']['bucket']['name']
    key = event['Records'][0]['s3']['object']['key']
    
    # One of a few different checks to ensure we don't end up in a recursive loop.
    if "-transcript.json" not in key: 
        print("This demo only works with *-transcript.json.")
        return
    
    try: 
        file_content = ""
        
        response = s3_client.get_object(Bucket=bucket, Key=key)
        
        file_content = response['Body'].read().decode('utf-8')
        
        transcript = extract_transcript_from_textract(file_content)

        print(f"Successfully read file {key} from bucket {bucket}.")

        print(f"Transcript: {transcript}")
        
        summary = bedrock_summarisation(transcript)
        
        s3_client.put_object(
            Bucket=bucket,
            Key='results.txt',
            Body=summary,
            ContentType='text/plain'
        )
        
    except Exception as e:
        print(f"Error occurred: {e}")
        return {
            'statusCode': 500,
            'body': json.dumps(f"Error occurred: {e}")
        }

    return {
        'statusCode': 200,
        'body': json.dumps(f"Successfully summarized {key} from bucket {bucket}. Summary: {summary}")
    }
        
        
        
def extract_transcript_from_textract(file_content):

    transcript_json = json.loads(file_content)

    output_text = ""
    current_speaker = None

    items = transcript_json['results']['items']

    # Iterate through the content word by word:
    for item in items:
        speaker_label = item.get('speaker_label', None)
        content = item['alternatives'][0]['content']
        
        # Start the line with the speaker label:
        if speaker_label is not None and speaker_label != current_speaker:
            current_speaker = speaker_label
            output_text += f"\n{current_speaker}: "
        
        # Add the speech content:
        if item['type'] == 'punctuation':
            output_text = output_text.rstrip()  # Remove the last space
        
        output_text += f"{content} "
        
    return output_text
        

def bedrock_summarisation(transcript):
    
    with open('prompt_template.txt', "r") as file:
        template_string = file.read()

    data = {
        'transcript': transcript,
        'topics': ['charges', 'location', 'availability']
    }
    
    template = Template(template_string)
    prompt = template.render(data)
    
    print(prompt)
    
    kwargs = {
        "modelId": "amazon.titan-text-express-v1",
        "contentType": "application/json",
        "accept": "*/*",
        "body": json.dumps(
            {
                "inputText": prompt,
                "textGenerationConfig": {
                    "maxTokenCount": 2048,
                    "stopSequences": [],
                    "temperature": 0,
                    "topP": 0.9
                }
            }
        )
    }
    
    response = bedrock_runtime.invoke_model(**kwargs)

    summary = json.loads(response.get('body').read()).get('results')[0].get('outputText')    
    return summary
# Out:
# Overwriting lambda_function.py

# %%
lambda_helper.deploy_function(
    ["lambda_function.py", "prompt_template.txt"],
    function_name="LambdaFunctionSummarize"
)
# Out:
# Zipping function...
# Looking for existing function...
# Function LambdaFunctionSummarize exists. Updating code...
# Function LambdaFunctionSummarize code updated: 2025-08-10T23:54:59.000+0000
# Done.

# %%
lambda_helper.filter_rules_suffix = "json"
lambda_helper.add_lambda_trigger(bucket_name_text)
# Out:
# Using function name of deployed function: LambdaFunctionSummarize
# Removed existing permission: s3-trigger-permission
# Permission added with Statement: {
#     "Sid": "s3-trigger-permission",
#     "Effect": "Allow",
#     "Principal": {
#         "Service": "s3.amazonaws.com"
#     },
#     "Action": "lambda:InvokeFunction",
#     "Resource": "arn:aws:lambda:us-west-2:092413168457:function:LambdaFunctionSummarize",
#     "Condition": {
#         "ArnLike": {
#             "AWS:SourceArn": "arn:aws:s3:::elephantscale-public-temp"
#         }
#     }
# }
# Trigger added for elephantscale-public-temp -> LambdaFunctionSummarize

# %%
# display_helper.json_file('demo-transcript.json')

# %%
s3_helper.upload_file(bucket_name_text, 'demo-transcript.json')
# Out:
# Object 'demo-transcript.json' uploaded to bucket 'elephantscale-public-temp'

# %% [markdown]
# #### Restart kernel if needed.
# - If you run the code fairly quickly from start to finish, it's possible that the following code cell `s3_helper.list_objects(bucket_name_text)` will give a "Not Found" error.
# - If waiting a few seconds (10 seconds) and re-running this cell does not resolve the error, then you can restart the kernel of the jupyter notebook.
# - Go to menu->Kernel->Restart Kernel.
# - Then run the code cells from the start of the notebook, waiting 2 seconds or so for each code cell to finish executing.

# %%
s3_helper.list_objects(bucket_name_text)
# Out:
# Object: .write_access_check_file.temp, Created on: 2025-08-10 23:48:31+00:00
# Object: Lesson_5_Knowledge_Base.json, Created on: 2024-11-25 03:52:31+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/14/data/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 14:33:24+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/16/data/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 16:32:47+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 03:56:11+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 05:02:54+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-04 03:16:05+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-12 21:37:37+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/14/00/data/amazon-bedrock-logs-permission-check, Created on: 2025-02-14 00:00:27+00:00
# Object: amazon_bedrock_large_data_delivery/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/data/amazon-bedrock-logs-permission-check, Created on: 2025-08-10 23:52:51+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/14/20241124T142909886Z_1650c2117c99c233.json.gz, Created on: 2024-11-24 14:29:10+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/14/20241124T143449110Z_5851190e1644939d.json.gz, Created on: 2024-11-24 14:34:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/14/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 14:33:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/14/data/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 14:33:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/16/20241124T163453581Z_5daaeeefe304a28b.json.gz, Created on: 2024-11-24 16:34:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/16/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 16:32:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/16/data/amazon-bedrock-logs-permission-check, Created on: 2024-11-24 16:32:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/20/20241124T204401007Z_20df0e57d9aa25e3.json.gz, Created on: 2024-11-24 20:44:02+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/24/21/20241124T214345613Z_f2602f094e52920f.json.gz, Created on: 2024-11-24 21:43:46+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/00/20241125T005946160Z_124e95be0b250ed8.json.gz, Created on: 2024-11-25 00:59:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/01/20241125T010909034Z_def0437b4895b30d.json.gz, Created on: 2024-11-25 01:09:10+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/01/20241125T011029170Z_8cd34ca2bd4ab99e.json.gz, Created on: 2024-11-25 01:10:30+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/03/20241125T035805675Z_248c26273242aa77.json.gz, Created on: 2024-11-25 03:58:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/04/20241125T040035869Z_9ed73558e2775bf5.json.gz, Created on: 2024-11-25 04:00:36+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/11/25/04/20241125T040102461Z_6e23d994a2218cc5.json.gz, Created on: 2024-11-25 04:01:03+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/20241203T032256059Z_b97e6d7441d2ae85.json.gz, Created on: 2024-12-03 03:22:57+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/20241203T035323076Z_69c6216409898758.json.gz, Created on: 2024-12-03 03:53:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/20241203T035733178Z_a7e7b658da1c8218.json.gz, Created on: 2024-12-03 03:57:34+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 03:56:11+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/03/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 03:56:11+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T040836661Z_680bb55bf1c426fe.json.gz, Created on: 2024-12-03 04:08:37+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T040946774Z_1ceae8d0fbd99b72.json.gz, Created on: 2024-12-03 04:09:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T041146907Z_bbb079776f107526.json.gz, Created on: 2024-12-03 04:11:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T041347021Z_195c7ddb1d786b15.json.gz, Created on: 2024-12-03 04:13:48+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T041547130Z_10bf93685be3144d.json.gz, Created on: 2024-12-03 04:15:48+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/04/20241203T041601527Z_52e54c94899dd5a4.json.gz, Created on: 2024-12-03 04:16:02+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/20241203T050017711Z_8c2ac05474be0ff8.json.gz, Created on: 2024-12-03 05:00:18+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/20241203T050142567Z_0a3c3a38ab672850.json.gz, Created on: 2024-12-03 05:01:43+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/20241203T050412743Z_20dc1d68f2557937.json.gz, Created on: 2024-12-03 05:04:13+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 05:02:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/05/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-03 05:02:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/20/20241203T204059731Z_10cb09435496c3b8.json.gz, Created on: 2024-12-03 20:41:00+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/20/20241203T204159739Z_f1fe2ac91901728a.json.gz, Created on: 2024-12-03 20:42:00+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/03/20/20241203T204359896Z_c7d0baacfcf7034d.json.gz, Created on: 2024-12-03 20:44:00+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/20241204T031507822Z_792a295e0b3a468f.json.gz, Created on: 2024-12-04 03:15:08+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/20241204T031624315Z_3a56b62afff0b20b.json.gz, Created on: 2024-12-04 03:16:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/20241204T031724314Z_637868f47be132cb.json.gz, Created on: 2024-12-04 03:17:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/amazon-bedrock-logs-permission-check, Created on: 2024-12-04 03:16:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/04/03/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-04 03:16:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/05/21/20241205T212050342Z_725ee8ef3d4ca7ae.json.gz, Created on: 2024-12-05 21:20:51+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/05/21/20241205T213435275Z_eb958fe441a97dff.json.gz, Created on: 2024-12-05 21:34:36+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/05/21/20241205T214305437Z_50483804d766e247.json.gz, Created on: 2024-12-05 21:43:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/05/21/20241205T214545567Z_92b9ea3bf3b66bc2.json.gz, Created on: 2024-12-05 21:45:46+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/06/02/20241206T021223936Z_6992650af2fa9913.json.gz, Created on: 2024-12-06 02:12:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/19/20241212T195701620Z_eb937833df695aea.json.gz, Created on: 2024-12-12 19:57:02+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/19/20241212T195811723Z_61a9cf320a9d8409.json.gz, Created on: 2024-12-12 19:58:12+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T200031838Z_ae7da608dcb09059.json.gz, Created on: 2024-12-12 20:00:32+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T200123253Z_19d54a492b660582.json.gz, Created on: 2024-12-12 20:01:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T200423352Z_c49eb7347235901b.json.gz, Created on: 2024-12-12 20:04:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T200603453Z_d2297a30a8273206.json.gz, Created on: 2024-12-12 20:06:04+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T200913624Z_98c4fef31a9a69a6.json.gz, Created on: 2024-12-12 20:09:14+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T201013620Z_6a876352a2d38140.json.gz, Created on: 2024-12-12 20:10:14+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T201133776Z_cb31ad7d37ec38d5.json.gz, Created on: 2024-12-12 20:11:34+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T201253874Z_d625a105fa334f6b.json.gz, Created on: 2024-12-12 20:12:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T201353872Z_a9148ff92a2657d8.json.gz, Created on: 2024-12-12 20:13:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T202031041Z_0b8f15726a84c4e5.json.gz, Created on: 2024-12-12 20:20:32+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T202231138Z_61ccaf2ac0eb11df.json.gz, Created on: 2024-12-12 20:22:32+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T202631278Z_289f67b3debef397.json.gz, Created on: 2024-12-12 20:26:32+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T202821375Z_92b7c4cf4c299179.json.gz, Created on: 2024-12-12 20:28:22+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T202951566Z_886d3e4a209d3404.json.gz, Created on: 2024-12-12 20:29:52+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T203146907Z_5ac889c1f46ead96.json.gz, Created on: 2024-12-12 20:31:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T203547030Z_d7f6e91e61921e54.json.gz, Created on: 2024-12-12 20:35:48+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T204614391Z_acf4fbedb2bb76dd.json.gz, Created on: 2024-12-12 20:46:15+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T205324537Z_ddbec1988d65cac5.json.gz, Created on: 2024-12-12 20:53:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/20/20241212T205954711Z_a56bcbe495a11403.json.gz, Created on: 2024-12-12 20:59:55+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T212534496Z_25d35737ebfd675d.json.gz, Created on: 2024-12-12 21:25:35+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T212654624Z_4019d7a3e32e42fe.json.gz, Created on: 2024-12-12 21:26:55+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T213004724Z_95719f44e1968612.json.gz, Created on: 2024-12-12 21:30:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T213353994Z_eaa29b0e7d2ea2d1.json.gz, Created on: 2024-12-12 21:33:55+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T213604093Z_7da07c6e901d6a75.json.gz, Created on: 2024-12-12 21:36:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T213704094Z_69d1ee9657605eca.json.gz, Created on: 2024-12-12 21:37:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/20241212T213904194Z_7e7b4053b67d90dc.json.gz, Created on: 2024-12-12 21:39:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/amazon-bedrock-logs-permission-check, Created on: 2024-12-12 21:37:37+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/12/21/data/amazon-bedrock-logs-permission-check, Created on: 2024-12-12 21:37:37+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/15/20241213T154310654Z_f9d77651c2a84e8f.json.gz, Created on: 2024-12-13 15:43:11+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/15/20241213T154924742Z_98efabc6244dc73f.json.gz, Created on: 2024-12-13 15:49:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/15/20241213T155144867Z_7bd728c20d3c6809.json.gz, Created on: 2024-12-13 15:51:45+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/15/20241213T155514995Z_513a4db8856e0d2f.json.gz, Created on: 2024-12-13 15:55:16+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/15/20241213T155825120Z_f4317a112be67338.json.gz, Created on: 2024-12-13 15:58:26+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T160154538Z_ae8b2f7d09049a8c.json.gz, Created on: 2024-12-13 16:01:55+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T160304638Z_f63aff2e2cade288.json.gz, Created on: 2024-12-13 16:03:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T160624869Z_1a0b594e25ad4b85.json.gz, Created on: 2024-12-13 16:06:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T160905002Z_972cb2ff7e6f64c8.json.gz, Created on: 2024-12-13 16:09:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T161035111Z_fa1d86922625222e.json.gz, Created on: 2024-12-13 16:10:36+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T161205255Z_93eaef036c050f51.json.gz, Created on: 2024-12-13 16:12:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T163216922Z_680419818034b63b.json.gz, Created on: 2024-12-13 16:32:17+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T163457044Z_b172b528209e0c81.json.gz, Created on: 2024-12-13 16:34:58+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T163947212Z_bebe6789b2584742.json.gz, Created on: 2024-12-13 16:39:48+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T164344595Z_318d3ca0922c0135.json.gz, Created on: 2024-12-13 16:43:45+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T164504694Z_08f1e05fc109e788.json.gz, Created on: 2024-12-13 16:45:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T164619772Z_7b0dd914692150c0.json.gz, Created on: 2024-12-13 16:46:20+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T164719766Z_9096ecfe6509d2b9.json.gz, Created on: 2024-12-13 16:47:20+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T164849897Z_70f3def0a07277b6.json.gz, Created on: 2024-12-13 16:48:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T165150085Z_b4248f6f567840c2.json.gz, Created on: 2024-12-13 16:51:51+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T165400274Z_85aab5a9c44d3a7d.json.gz, Created on: 2024-12-13 16:54:01+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/16/20241213T165810445Z_513bdb38b5a68af1.json.gz, Created on: 2024-12-13 16:58:11+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T182118901Z_1c3f531847358b5c.json.gz, Created on: 2024-12-13 18:21:19+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T182439068Z_b205e33f57a36cf7.json.gz, Created on: 2024-12-13 18:24:40+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T182819200Z_3b8f0590d232e4fa.json.gz, Created on: 2024-12-13 18:28:20+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T183638606Z_3047c9b2b782c0a9.json.gz, Created on: 2024-12-13 18:36:39+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T183848715Z_b88dc7556f1b9514.json.gz, Created on: 2024-12-13 18:38:49+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T184048870Z_c37eca5440f4fa3e.json.gz, Created on: 2024-12-13 18:40:49+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T184248990Z_007422beda2dd7d4.json.gz, Created on: 2024-12-13 18:42:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T184348991Z_3c8fae5baec0cc0c.json.gz, Created on: 2024-12-13 18:43:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T184758020Z_367db193b57f7305.json.gz, Created on: 2024-12-13 18:47:59+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T184908155Z_bea3170edd764319.json.gz, Created on: 2024-12-13 18:49:09+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/18/20241213T185208281Z_acc90ad39f8ac663.json.gz, Created on: 2024-12-13 18:52:09+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T190224246Z_a884205ac9300519.json.gz, Created on: 2024-12-13 19:02:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T192127309Z_e1dbe789e57acdb3.json.gz, Created on: 2024-12-13 19:21:28+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T192507404Z_f9be4a1ea3de1068.json.gz, Created on: 2024-12-13 19:25:08+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T192707548Z_383d6aae403d6b3b.json.gz, Created on: 2024-12-13 19:27:08+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T193007650Z_9a03cac177de2670.json.gz, Created on: 2024-12-13 19:30:08+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T193149741Z_b7b8449348a6964f.json.gz, Created on: 2024-12-13 19:31:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T193349887Z_dd436a94ccc36b20.json.gz, Created on: 2024-12-13 19:33:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T193510015Z_c5b12cb737172238.json.gz, Created on: 2024-12-13 19:35:11+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T194330374Z_b433dc8ce0ab1924.json.gz, Created on: 2024-12-13 19:43:31+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T194616006Z_229db2bd6cb95236.json.gz, Created on: 2024-12-13 19:46:17+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T194726220Z_8b5f7ae70992631a.json.gz, Created on: 2024-12-13 19:47:27+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T195106362Z_d529dfd44e6978c6.json.gz, Created on: 2024-12-13 19:51:07+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T195306492Z_f2dbc3cd6d7f619e.json.gz, Created on: 2024-12-13 19:53:07+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T195536650Z_12877da11189362a.json.gz, Created on: 2024-12-13 19:55:37+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2024/12/13/19/20241213T195656820Z_b636c83af510586d.json.gz, Created on: 2024-12-13 19:56:57+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/01/03/18/20250103T183444486Z_f252049e28f9e908.json.gz, Created on: 2025-01-03 18:34:45+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/01/03/18/20250103T184705273Z_992770f30a176aaf.json.gz, Created on: 2025-01-03 18:47:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/22/20250212T225611812Z_f6a4d81cb1926955.json.gz, Created on: 2025-02-12 22:56:12+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/22/20250212T225711804Z_e42961c425b6bea3.json.gz, Created on: 2025-02-12 22:57:12+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/22/20250212T225821910Z_95aa8dfcc21eef1a.json.gz, Created on: 2025-02-12 22:58:22+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T230052069Z_5d5a275736cddc66.json.gz, Created on: 2025-02-12 23:00:53+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T230055235Z_c5bee75372ad8620.json.gz, Created on: 2025-02-12 23:00:56+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T230155248Z_71da2d2a6cc4a82e.json.gz, Created on: 2025-02-12 23:01:56+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T230405389Z_c5cbbfe521c1be82.json.gz, Created on: 2025-02-12 23:04:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T230825505Z_54175ac9b6ec577d.json.gz, Created on: 2025-02-12 23:08:26+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T231055648Z_18653fb0b138aae9.json.gz, Created on: 2025-02-12 23:10:56+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T231205761Z_2b247a4da69f8b0f.json.gz, Created on: 2025-02-12 23:12:06+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T231325894Z_19b5f94a5423d6a8.json.gz, Created on: 2025-02-12 23:13:26+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T232301939Z_7d76c55a33dd8c18.json.gz, Created on: 2025-02-12 23:23:02+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T232452073Z_95aa056320320e2e.json.gz, Created on: 2025-02-12 23:24:53+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233002269Z_8bbec8d1aec29617.json.gz, Created on: 2025-02-12 23:30:03+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233243897Z_3b2d9d71bfeacc10.json.gz, Created on: 2025-02-12 23:32:44+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233604050Z_845c71f720e0be0c.json.gz, Created on: 2025-02-12 23:36:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233704046Z_bfaa77395cef1c94.json.gz, Created on: 2025-02-12 23:37:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233804092Z_0a5464075cce1e89.json.gz, Created on: 2025-02-12 23:38:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T233904086Z_1b15a2f55946a63b.json.gz, Created on: 2025-02-12 23:39:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T234014204Z_f22491b3111fff20.json.gz, Created on: 2025-02-12 23:40:15+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T234154302Z_4ef969762ed8cce1.json.gz, Created on: 2025-02-12 23:41:55+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T234603370Z_ca889feed02275d9.json.gz, Created on: 2025-02-12 23:46:04+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/12/23/20250212T235453616Z_e88b355e6eeb5323.json.gz, Created on: 2025-02-12 23:54:54+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/13/23/20250213T235846148Z_af939400bb8a3e35.json.gz, Created on: 2025-02-13 23:58:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/14/00/20250214T000145482Z_e2a93c2368428c3b.json.gz, Created on: 2025-02-14 00:01:46+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/14/00/20250214T001623529Z_6da3c1b397fb6d92.json.gz, Created on: 2025-02-14 00:16:24+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/14/00/amazon-bedrock-logs-permission-check, Created on: 2025-02-14 00:00:27+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/02/14/00/data/amazon-bedrock-logs-permission-check, Created on: 2025-02-14 00:00:27+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/20/20250810T205813295Z_7fc7d535d34c07a9.json.gz, Created on: 2025-08-10 20:58:14+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T210013464Z_56b7cbb085c595c4.json.gz, Created on: 2025-08-10 21:00:14+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T210149608Z_c825e81ff4d86f46.json.gz, Created on: 2025-08-10 21:01:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T210249617Z_803a848e030adebc.json.gz, Created on: 2025-08-10 21:02:50+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T210539727Z_a214617358c1d267.json.gz, Created on: 2025-08-10 21:05:40+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T212220439Z_c228b33fa8b01726.json.gz, Created on: 2025-08-10 21:22:21+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T212330539Z_af9044a8f562085b.json.gz, Created on: 2025-08-10 21:23:31+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/21/20250810T212440642Z_ccd72020d62036bd.json.gz, Created on: 2025-08-10 21:24:41+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/22/20250810T221924398Z_6aa3522a9b5c6b80.json.gz, Created on: 2025-08-10 22:19:25+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/22/20250810T222304519Z_b471f3778d0df070.json.gz, Created on: 2025-08-10 22:23:05+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/22/20250810T225133867Z_01d0943c3a254efa.json.gz, Created on: 2025-08-10 22:51:34+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/20250810T232439816Z_bba27549273e7cef.json.gz, Created on: 2025-08-10 23:24:40+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/20250810T234646561Z_6e4c2c293b6b5816.json.gz, Created on: 2025-08-10 23:46:47+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/20250810T234826649Z_277bba6a449eda97.json.gz, Created on: 2025-08-10 23:48:27+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/20250810T235016755Z_6cc00ebe6b7187a4.json.gz, Created on: 2025-08-10 23:50:17+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/20250810T235406865Z_1bf658a24fdf5d2c.json.gz, Created on: 2025-08-10 23:54:07+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/amazon-bedrock-logs-permission-check, Created on: 2025-08-10 23:52:51+00:00
# Object: amazon_bedrock_logs/AWSLogs/092413168457/BedrockModelInvocationLogs/us-west-2/2025/08/10/23/data/amazon-bedrock-logs-permission-check, Created on: 2025-08-10 23:52:51+00:00
# Object: demo-transcript.json, Created on: 2025-08-10 23:59:03+00:00
# Object: dialog.mp3, Created on: 2025-08-10 23:48:27+00:00
# Object: transcription-job-0a273266-b1cf-47e4-b274-40500a221fe5.json, Created on: 2024-11-24 01:00:20+00:00
# Object: transcription-job-0aeffc87-99bd-405e-8f7e-eccbf00d7030.json, Created on: 2025-02-12 22:59:37+00:00
# Object: transcription-job-16c08443-5b8d-4de7-acd0-f5848f0be4f2.json, Created on: 2025-02-12 23:08:56+00:00
# Object: transcription-job-1c0a4efd-1518-416d-8f68-424f9460bdd7.json, Created on: 2024-11-14 04:29:27+00:00
# Object: transcription-job-29e23884-ad34-4975-a1b2-058e641132d9.json, Created on: 2024-11-08 04:56:52+00:00
# Object: transcription-job-3648c8c9-0446-4384-857e-b23b2154fd98.json, Created on: 2024-12-03 03:52:26+00:00
# Object: transcription-job-3e244bd1-cd2e-423b-ab84-733e23621fd2.json, Created on: 2024-12-12 20:57:41+00:00
# Object: transcription-job-3e38440c-ad25-41d4-8701-ca10b851316d.json, Created on: 2025-08-10 23:48:51+00:00
# Object: transcription-job-5dc4b882-8ac7-4892-b2a2-88291e26d1a2.json, Created on: 2024-12-04 03:15:22+00:00
# Object: transcription-job-70e7bd30-2b45-4af1-8e3f-f46c87258744.json, Created on: 2024-12-12 20:47:46+00:00
# Object: transcription-job-7f06770c-4076-407f-bc6f-75188373a149.json, Created on: 2024-12-12 20:43:47+00:00
# Object: transcription-job-92a0188b-cb4e-4c4f-b47d-f3f522ab3e75.json, Created on: 2024-12-12 20:43:48+00:00
# Object: transcription-job-9386c109-23c9-410c-bad5-0dc282330eb6.json, Created on: 2024-12-03 05:00:37+00:00
# Object: transcription-job-a3e6af8b-23c0-4c04-8922-83ade7303281.json, Created on: 2024-12-05 21:44:42+00:00
# Object: transcription-job-cc34de7c-1f54-4ce0-b434-090cb6bd4967.json, Created on: 2025-02-12 23:09:07+00:00
# Object: transcription-job-d3d53154-1527-427a-b539-07cafa87e8ac.json, Created on: 2025-02-12 23:07:29+00:00

# %% [markdown]
# #### Re-run "download" code cell as needed
# - It may take a few seconds for the results to be generated.
# - If you see a `Not Found` error, please wait a few seconds and then try running the `s3_helper.download_object` again.

# %%
s3_helper.download_object(bucket_name_text, "results.txt")
# Out:
# Error: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
display_helper.text_file('results.txt')
# Out:
# The file results.txt was not found.
